# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud


# We do this to ignore several specific Pandas warnings
import warnings

# %%
# ls

# %%
from wordcloud import STOPWORDS
print(STOPWORDS) # a set of words
# Out:
# {"haven't", 'themselves', "you'd", "there's", 'them', 'her', 'by', 'doing', 'a', 'very', "don't", 'from', 'own', "you'll", "wouldn't", 'out', 'me', 'of', 'all', 'both', "we've", 'ever', "can't", 'their', 'because', 'com', 'each', "doesn't", "he'd", 'she', 'these', 'could', 'more', 'no', "didn't", "hadn't", 'same', 'not', 'just', 'it', 'your', 'whom', 'until', 'my', "i'll", 'cannot', 'here', 'ought', "it's", 'or', 'is', 'should', "we'll", 'so', "weren't", 'his', 'with', "aren't", 'the', 'why', 'otherwise', 'to', 'www', 'http', "where's", 'we', "let's", 'most', 'against', "she's", 'ours', "he's", "won't", 'been', 'however', 'myself', 'few', "they're", 'over', 'yours', 'any', 'further', "mustn't", 'our', 'get', "why's", 'above', "she'll", 'after', 'had', 'up', 'into', 'through', 'yourselves', 'than', 'there', 'when', 'between', 'shall', "hasn't", 'theirs', 'do', 'also', 'i', 'but', 'r', 'what', 'that', 'are', 'therefore', "here's", 'k', 'herself', 'nor', "couldn't", 'itself', 'did', 'if
# ...

# %%
with open("atiku_tweet.txt", encoding="utf8") as file:
    data = file.read()

# %%
# create wordcloud using data
wordcloud = WordCloud().generate(data)

# show wordcloud using matplotlib
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud2 = WordCloud(collocations = False, background_color = 'white', width=2500, height=2000).generate(data)

# Display the generated Word Cloud

plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")
plt.savefig('atiku_tweet_word_cloud.png')
plt.show()
